# %%
# !pip install langchain 
# !pip install llama-index 
# !pip install chromadb 
# !pip install faiss-cpu 
# !pip install sentence-transformers 
# !pip install PyPDF2 
# !pip install streamlit 
# !pip install transformers 
# !pip install torch
# Out:
# ...
#   Using cached langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.3.18-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached langsmith-0.1.143-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached orjson-3.10.11-cp312-none-win_amd64.whl.metadata (52 kB)
# ...
# Using cached langchain-0.3.7-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.18-py3-none-any.whl (409 kB)
# Using cached langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.143-py3-none-any.whl (306 kB)
# Using cached orjson-3.10.11-cp312-none-win_amd64.whl (136 kB)
# ...
#   Using cached llama_index-0.11.23-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached llama_index_agent_openai-0.3.4-py3-none-any.whl.metadata (728 bytes)
# ...
#   Using cached llama_index_cli-0.3.1-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached llama_index_core-0.11.23-py3-none-any.whl.metadata (2.5 kB)
# ...

# %%
from PyPDF2 import PdfReader

def extract_text_from_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Example usage
alphabet_text = extract_text_from_pdf("goog-10-k-2023 (1).pdf")
tesla_text = extract_text_from_pdf("tsla-20231231-gen.pdf")
uber_text = extract_text_from_pdf("uber-10-k-2023.pdf")
documents = [alphabet_text, tesla_text, uber_text]

# %%
from sentence_transformers import SentenceTransformer

# Load embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings for documents
embeddings = [model.encode(doc) for doc in documents]
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\panka\Downloads\anaconda\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\panka\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# !pip install chromadb
import chromadb
from chromadb.config import Settings

client = chromadb.Client(Settings())

# Create a collection
collection = client.create_collection(name="content_engine")

# Add embeddings to the collection
for i, embedding in enumerate(embeddings):
    collection.add(
        embeddings=[embedding],
        metadatas=[{"document_id": i}],
        ids=[f"doc_{i}"]
    )
# Out:
# ...
#   Using cached chromadb-0.5.18-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# ...
#   Using cached opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# ...

# %%
def query_engine(query, collection):
    query_embedding = model.encode(query)
    results = collection.query(query_embeddings=[query_embedding], n_results=3)
    return results

# Example query
query = "What are the risk factors associated with Google and Tesla?"
results = query_engine(query, collection)
print(results)
# Out:
# {'ids': [['doc_1', 'doc_2', 'doc_0']], 'embeddings': None, 'documents': [[None, None, None]], 'uris': None, 'data': None, 'metadatas': [[{'document_id': 1}, {'document_id': 2}, {'document_id': 0}]], 'distances': [[1.6349419355392456, 1.677229881286621, 1.945066213607788]], 'included': [<IncludeEnum.distances: 'distances'>, <IncludeEnum.documents: 'documents'>, <IncludeEnum.metadatas: 'metadatas'>]}

# %%
# !pip install gpt4all
# Out:
# ...
#    ---------------------------------------- 0.0/119.6 MB ? eta -:--:--
#    - -------------------------------------- 5.0/119.6 MB 27.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 15.2/119.6 MB 38.2 MB/s eta 0:00:03
#    -------- ------------------------------- 25.2/119.6 MB 40.9 MB/s eta 0:00:03
#    ------------ --------------------------- 35.9/119.6 MB 43.1 MB/s eta 0:00:02
#    --------------- ------------------------ 46.1/119.6 MB 44.5 MB/s eta 0:00:02
#    ------------------ --------------------- 56.1/119.6 MB 45.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 66.3/119.6 MB 45.5 MB/s eta 0:00:02
#    ------------------------- -------------- 77.1/119.6 MB 45.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 87.6/119.6 MB 46.6 MB/s eta 0:00:01
#    -------------------------------- ------- 98.0/119.6 MB 47.1 MB/s eta 0:00:01
#    ----------------------------------- --- 109.1/119.6 MB 47.4 MB/s eta 0:00:01
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")
model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")

def generate_response(prompt):
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(inputs['input_ids'], max_new_tokens=100)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

response = generate_response("What are the risk factors for Google?")
print(response)
# Out:
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# c:\Users\panka\Downloads\anaconda\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\panka\.cache\huggingface\hub\models--EleutherAI--gpt-neo-1.3B. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
import streamlit as st

st.title("Content Engine Chatbot")
user_input = st.text_input("Ask your query:")

if user_input:
    query_results = query_engine(user_input, collection)
    context = "\n".join([res['metadata']['text'] for res in query_results['results']])
    response = generate_response(f"Based on this context: {context}, answer: {user_input}")
    st.write("Response:", response)
# Out:
# 2024-11-15 18:30:48.745
# ...
#   command:
#
#     streamlit run c:\Users\panka\Downloads\anaconda\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-15 18:30:48.749 Session state does not function when running a script without `streamlit run`
